# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Telecom_customer_churn.csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %% [markdown]
# There are total 7043 rows and 21 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# Here we can see we dont have any null value and datatype is also showing

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# here we can see all the values are in object or float datatypes

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# Using isnull we saw that we dont have any null value present

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# plotting heatmap also we checked that there is no null value present in the datasets

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# Here we got statistic value of datasets

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# here we can see all the columns present in our dataset

# %%
df['Churn'].nunique()
# Out:
# 2

# %% [markdown]
# here we can see target variable have 2 unique values

# %% [markdown]
# # EDA

# %%
sns.countplot(df["Churn"]);

# %% [markdown]
# We can see that target is not balanced

# %%
sns.countplot(hue='Churn',x='gender',data=df)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# here we can see In both yes and no category female is high and male is low

# %%
sns.countplot(x='Partner',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='Partner', ylabel='count'>

# %% [markdown]
# here we can see In both yes and no category patner churn  is high in yes and low in No

# %%
sns.countplot(x='Dependents',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='count'>

# %% [markdown]
# here we can see In both yes and no category Depends is high in no and low in yes

# %%
sns.countplot(x='MultipleLines',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='MultipleLines', ylabel='count'>

# %% [markdown]
# here we can see In both yes and no category MulitpleLines is high in no and low in No phone service

# %%
sns.countplot(x='InternetService',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='InternetService', ylabel='count'>

# %% [markdown]
# here we can see In both yes and no category DSL is high  and low in NO

# %%
sns.countplot(x='OnlineSecurity',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='OnlineSecurity', ylabel='count'>

# %% [markdown]
# here we can see In both yes and no category Online Security  is high in no and low in No internet service

# %%
sns.countplot(x='OnlineBackup',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='OnlineBackup', ylabel='count'>

# %% [markdown]
# here we can see In both yes and no category OnlineBackup is high in Yes and low in No internet

# %%
sns.countplot(x='DeviceProtection',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='DeviceProtection', ylabel='count'>

# %% [markdown]
# here we can see In both yes and no category DeviceProtection is high in No and yes both is equal and low in No internet service

# %%
sns.countplot(x='SeniorCitizen',hue='Churn',data=df)
# Out:
# <AxesSubplot:xlabel='SeniorCitizen', ylabel='count'>

# %% [markdown]
# here we can see In both yes and no category SeniorCitizen is high in 0 and low in 1

# %%
sns.boxplot(x="Churn", y="tenure", data=df,palette='rainbow');

# %% [markdown]
# Here we can see that Yes outliers is present so we need to remove

# %%
sns.boxplot(x="Churn", y="MonthlyCharges", data=df,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='MonthlyCharges'>

# %% [markdown]
# Here we can see no outliers is present

# %%
sns.pairplot(df,hue='Churn',palette='rainbow')

# %% [markdown]
# Here we can see that tenure we have more sattered value

# %%
df['Churn'].value_counts().plot.pie(figsize = (5,5), autopct = '%.1f%%')
# Out:
# <AxesSubplot:ylabel='Churn'>

# %% [markdown]
# Here we can observe that no is 73% high and Yes is 26.5%

# %%
df['gender'].value_counts().plot.pie(figsize = (5,5), autopct = '%.1f%%')
# Out:
# <AxesSubplot:ylabel='gender'>

# %% [markdown]
# Here we can observe that Male is 50.5% high and FeMale is 49.5%

# %%
df['InternetService'].value_counts().plot.pie(figsize = (5,5), autopct = '%.1f%%')
# Out:
# <AxesSubplot:ylabel='InternetService'>

# %% [markdown]
# Here we can observe that DSL is 34.4%  and No is 21.7% and Fiber optic which is highest is 44.0%

# %%
for i in df.columns:
    if df[i].dtypes!=object:
        sns.boxplot(df[i]) 
        plt.show()

# %% [markdown]
# Here we can see only seniorcitzen have outliers present

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in df.columns:
    if df[i].dtypes==object:
        df[i]=le.fit_transform(df[i])
df
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0           5375       0              0        1           0       1
# 1           3962       1              0        0           0      34
# 2           2564       1              0        0           0       2
# 3           5535       1              0        0           0      45
# 4           6511       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038        4853       1              0        1           1      24
# 7039        1525       0              0        1           1      72
# 7040        3367       0              0        1           1      11
# 7041        5934       1              1        1           0       4
# 7042        2226       1              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
#Set up a category plot
g=sns.catplot(x="InternetService",y="Churn",data=df,kind="violin")
#show plot
plt.show()

# %% [markdown]
# Here we can see that internetservice is scattered more at 2

# %%
for i in df.columns:
    if df[i].dtypes!=object:
        sns.distplot(df[i]) 
        plt.show()

# %% [markdown]
# Here we can predict only customerId is almost normally distributed rest is not distributed normally that means skweness is present

# %%
cor=df.corr()
cor
# Out:
#                   customerID    gender  SeniorCitizen   Partner  Dependents  \
# customerID          1.000000  0.006288      -0.002074 -0.026729   -0.012823
# gender              0.006288  1.000000      -0.001874 -0.001808    0.010517
# SeniorCitizen      -0.002074 -0.001874       1.000000  0.016479   -0.211185
# Partner            -0.026729 -0.001808       0.016479  1.000000    0.452676
# Dependents         -0.012823  0.010517      -0.211185  0.452676    1.000000
# tenure              0.008035  0.005106       0.016567  0.379697    0.159712
# PhoneService       -0.006483 -0.006488       0.008576  0.017706   -0.001762
# MultipleLines       0.004316 -0.006739       0.146185  0.142410   -0.024991
# InternetService    -0.012407 -0.000863      -0.032310  0.000891    0.044590
# OnlineSecurity      0.013292 -0.015017      -0.128221  0.150828    0.152166
# OnlineBackup       -0.003334 -0.012057      -0.013632  0.153130    0.091015
# ...

# %%
plt.figure(figsize=(22,7))
df.corr()['Churn'].sort_values(ascending=False).drop(['Churn']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# Here we can observe that from montlychareges to customerid is postive correleated after that till contact it is drastically getting in negative corrleation

# %%
plt.figure(figsize=[22,12])
sns.heatmap(cor,annot=True)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# Here we can observe Tenure with contract is 67% correlated

# %%
#Boxplot Display distribution of data across all level of category
df.boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [markdown]
# Here we can see now only few outliers are present in the columns

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
new_df=df[(z<3).all(axis=1)]
new_df
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 1           3962       1              0        0           0      34
# 2           2564       1              0        0           0       2
# 4           6511       0              0        0           0       2
# 5           6551       0              0        0           0       8
# 6           1002       1              0        0           1      22
# ...          ...     ...            ...      ...         ...     ...
# 7037        1758       0              0        0           0      72
# 7038        4853       1              0        1           1      24
# 7039        1525       0              0        1           1      72
# 7041        5934       1              1        1           0       4
# 7042        2226       1              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
new_df.shape
# Out:
# (6361, 21)

# %%
Data_loss=((7043-6361)/7043*100)                      
Data_loss
# Out:
# 9.683373562402386

# %% [markdown]
# we can use the new df because data is not much lost

# %%
new_df.skew()
# Out:
# customerID          0.006843
# gender             -0.014781
# SeniorCitizen       1.823376
# Partner             0.056316
# Dependents          0.876594
# tenure              0.237945
# PhoneService        0.000000
# MultipleLines       0.132058
# InternetService     0.049126
# OnlineSecurity      0.422032
# OnlineBackup        0.167910
# DeviceProtection    0.183254
# TechSupport         0.409833
# StreamingTV        -0.002734
# StreamingMovies    -0.010025
# Contract            0.629701
# PaperlessBilling   -0.386613
# PaymentMethod      -0.169889
# MonthlyCharges     -0.399139
# TotalCharges       -0.041683
# Churn               1.053055
# dtype: float64

# %% [markdown]
# still many value skewness is not removed we need to remove oskweness or else model will not be builder properly

# %% [markdown]
# # Variance Inflation Factor(VIF):¶
# Used for finding multi colenearity.So,that we can remove it

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def cal_vif(ds):
    vif=pd.DataFrame()
    vif["variables"]=ds.columns
    vif["VIF FACTOR"]=[variance_inflation_factor (ds.values,i) for i in range (ds.shape[1])]
    return (vif)

cal_vif(new_df)
# Out:
#            variables  VIF FACTOR
# 0         customerID    1.002965
# 1             gender    1.002134
# 2      SeniorCitizen    1.154638
# 3            Partner    1.471112
# 4         Dependents    1.386681
# 5             tenure    2.931687
# 6       PhoneService   28.047351
# 7      MultipleLines    1.418115
# 8    InternetService    1.593545
# 9     OnlineSecurity    1.259758
# 10      OnlineBackup    1.204660
# 11  DeviceProtection    1.277536
# 12       TechSupport    1.317984
# 13       StreamingTV    1.443760
# 14   StreamingMovies    1.445642
# 15          Contract    2.522062
# 16  PaperlessBilling    1.220144
# 17     PaymentMethod    1.179037
# 18    MonthlyCharges    2.898453
# 19      TotalCharges    1.121720
# 20             Churn    1.376147

# %% [markdown]
# Phoneservice is highly correlated

# %%
plt.figure(figsize=(15,14))
normalDist=1
for i in new_df:
    if normalDist<=10:
        plt.subplot(4,3,normalDist)
        sns.distplot(new_df[i])
        plt.xlabel(i)
    normalDist=normalDist+1
plt.show()

# %% [markdown]
# from early graph we can see skewness is little reduce compare to last plot

# %%
x=df.drop(['Churn'],axis=1)
y=df['Churn']

# %%
y.value_counts()
# Out:
# 0    5174
# 1    1869
# Name: Churn, dtype: int64

# %% [markdown]
# we can see target is imbalance

# %%
sns.countplot(y)
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='count'>

# %% [markdown]
# using countplot also we can see the difference

# %%
from sklearn.preprocessing import power_transform
new_df=power_transform(x)

new_df=pd.DataFrame(new_df,columns=x.columns)
new_df.skew()
# Out:
# customerID         -0.290930
# gender             -0.019031
# SeniorCitizen       1.833633
# Partner             0.067922
# Dependents          0.875199
# tenure             -0.243325
# PhoneService       -2.727153
# MultipleLines       0.033697
# InternetService    -0.072384
# OnlineSecurity      0.149362
# OnlineBackup       -0.001417
# DeviceProtection    0.001051
# TechSupport         0.139751
# StreamingTV        -0.097211
# StreamingMovies    -0.105641
# Contract            0.302174
# PaperlessBilling   -0.375396
# PaymentMethod      -0.207559
# MonthlyCharges     -0.259035
# TotalCharges       -0.290854
# dtype: float64

# %% [markdown]
# # SMOTE

# %%
from imblearn.over_sampling import SMOTE
SM=SMOTE()
X,Y=SM.fit_resample(x,y)

# %%
Y.value_counts()
# Out:
# 0    5174
# 1    5174
# Name: Churn, dtype: int64

# %% [markdown]
# Now we can see target is balanced

# %%
sns.countplot(Y)
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='count'>

# %% [markdown]
# here also we can see values are balanced

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.linear_model import LogisticRegression

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=.20,random_state=i)
    mod=LogisticRegression()
    mod.fit(X_train,Y_train)
    pred=mod.predict(X_test)
    acc=accuracy_score(Y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best Accuracy is',maxAccu,' on Random state',maxRS)
# Out:
# Best Accuracy is 0.8256038647342995  on Random state 92

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=.33,random_state=92)

# %%
#LOGISTIC REGRESSION
log=LogisticRegression()
log.fit(X_train,Y_train)
pred_log=log.predict(X_test)
print('accuracy score',accuracy_score(Y_test,pred_log))
print(confusion_matrix(Y_test,pred_log))
print(classification_report(Y_test,pred_log))
# Out:
# accuracy score 0.8128843338213763
# [[1340  383]
#  [ 256 1436]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81      1723
#            1       0.79      0.85      0.82      1692
#
#     accuracy                           0.81      3415
#    macro avg       0.81      0.81      0.81      3415
# weighted avg       0.81      0.81      0.81      3415

# %%
#DECISION TREE CLASSIFIER
from sklearn.tree import DecisionTreeClassifier
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=.33,random_state=92)
dtc= DecisionTreeClassifier()
dtc.fit(X_train,Y_train)
pred_dtc=dtc.predict(X_test)
print('accuracy_score:',accuracy_score(Y_test,pred_dtc))
print("confusion matrix:",confusion_matrix(Y_test,pred_dtc))
print("classification report:",classification_report(Y_test,pred_dtc))
# Out:
# accuracy_score: 0.7847730600292826
# confusion matrix: [[1345  378]
#  [ 357 1335]]
# classification report:               precision    recall  f1-score   support
#
#            0       0.79      0.78      0.79      1723
#            1       0.78      0.79      0.78      1692
#
#     accuracy                           0.78      3415
#    macro avg       0.78      0.78      0.78      3415
# weighted avg       0.78      0.78      0.78      3415

# %%
#RANDOM FOREST CLASSIFIER
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=10,criterion='entropy',random_state=92)
rfc.fit(X_train,Y_train)
pred_rfc=rfc.predict(X_test)
print('accuracy_score:',accuracy_score(Y_test,pred_rfc))
print("confusion matrix:",confusion_matrix(Y_test,pred_rfc))
print("classification report:",classification_report(Y_test,pred_rfc))
# Out:
# accuracy_score: 0.829575402635432
# confusion matrix: [[1488  235]
#  [ 347 1345]]
# classification report:               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.84      1723
#            1       0.85      0.79      0.82      1692
#
#     accuracy                           0.83      3415
#    macro avg       0.83      0.83      0.83      3415
# weighted avg       0.83      0.83      0.83      3415

# %%
#KNEIGHBORS CLASSIFIER
from sklearn.neighbors import KNeighborsClassifier
knc=KNeighborsClassifier(n_neighbors=10)
knc.fit(X_train,Y_train)
pred_knc=knc.predict(X_test)
print('accuracy_score:',accuracy_score(Y_test,pred_knc))
print("confusion matrix:",confusion_matrix(Y_test,pred_knc))
print("classification report:",classification_report(Y_test,pred_knc))
# Out:
# accuracy_score: 0.6269399707174231
# confusion matrix: [[1066  657]
#  [ 617 1075]]
# classification report:               precision    recall  f1-score   support
#
#            0       0.63      0.62      0.63      1723
#            1       0.62      0.64      0.63      1692
#
#     accuracy                           0.63      3415
#    macro avg       0.63      0.63      0.63      3415
# weighted avg       0.63      0.63      0.63      3415

# %%
#SUPPORT VECTOR MACHINE
from sklearn.svm import SVC
svc2=SVC(kernel='rbf')
svc2.fit(X_train,Y_train)
pred_svc2=svc2.predict(X_test)
print('accuracy_score:',accuracy_score(Y_test,pred_svc2))
print("confusion matrix:",confusion_matrix(Y_test,pred_svc2))
print("classification report:",classification_report(Y_test,pred_svc2))
# Out:
# accuracy_score: 0.5320644216691068
# confusion matrix: [[986 737]
#  [861 831]]
# classification report:               precision    recall  f1-score   support
#
#            0       0.53      0.57      0.55      1723
#            1       0.53      0.49      0.51      1692
#
#     accuracy                           0.53      3415
#    macro avg       0.53      0.53      0.53      3415
# weighted avg       0.53      0.53      0.53      3415

# %% [markdown]
# # cross_val_score

# %%
from sklearn.model_selection import cross_val_score
cv=cross_val_score(log,X,Y,cv=10)
print("mean score:",cv.mean())
print("cross val score for LOGISTIC REGRESSION:",cv)
# Out:
# mean score: 0.8069259664171783
# cross val score for LOGISTIC REGRESSION: [0.76425121 0.76231884 0.72850242 0.7826087  0.82705314 0.83864734
#  0.84154589 0.84057971 0.84042553 0.84332689]

# %%
cv=cross_val_score(knc,x,y,cv=10)
print("mean score:",cv.mean())
print("cross val score KNEIGHBORS CLASSIFIER:",cv)
# Out:
# mean score: 0.723269866215345
# cross val score KNEIGHBORS CLASSIFIER: [0.72198582 0.72624113 0.73191489 0.71732955 0.71732955 0.73153409
#  0.72585227 0.70596591 0.73579545 0.71875   ]

# %%
cv=cross_val_score(dtc,x,y,cv=10)
print("mean score:",cv.mean())
print("cross val score DECISION TREE CLASSIFIER:",cv)
# Out:
# mean score: 0.719863193101225
# cross val score DECISION TREE CLASSIFIER: [0.70496454 0.73049645 0.72765957 0.6875     0.72727273 0.72869318
#  0.70880682 0.72727273 0.71306818 0.74289773]

# %%
cv=cross_val_score(svc2,x,y,cv=10)
print("mean score:",cv.mean())
print("cross val score SUPPORT VECTOR MACHINE:",cv)
# Out:
# mean score: 0.7346300773694391
# cross val score SUPPORT VECTOR MACHINE: [0.73475177 0.73475177 0.73475177 0.73579545 0.734375   0.734375
#  0.734375   0.734375   0.734375   0.734375  ]

# %%
cv=cross_val_score(rfc,x,y,cv=10)
print("mean score:",cv.mean())
print("cross val score RANDOM FOREST CLASSIFIER:",cv)
# Out:
# mean score: 0.7861688023855578
# cross val score RANDOM FOREST CLASSIFIER: [0.79148936 0.80283688 0.77730496 0.78977273 0.77414773 0.75994318
#  0.78693182 0.77982955 0.78977273 0.80965909]

# %% [markdown]
# We found that  RANDOM FOREST CLASSIFIER is best with least difference

# %% [markdown]
# # HyperTuning of the model

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {'max_depth': [10, 20, 30, 40, None],
                  'max_features': ['auto', 'sqrt'],
                  'min_samples_leaf': [1, 2, 4],
                  'min_samples_split': [2, 5, 10],
                  'n_estimators': [5, 10, 20, 30, 50]}

GCV=GridSearchCV(rfc,parameters,cv=5)
GCV.fit(X_train,Y_train)
GCV.best_params_
# Out:
# {'max_depth': 40,
#  'max_features': 'auto',
#  'min_samples_leaf': 1,
#  'min_samples_split': 5,
#  'n_estimators': 50}

# %%
from sklearn.metrics import roc_curve,roc_auc_score
Finalmod=RandomForestClassifier(max_depth=40,max_features='auto',min_samples_leaf=1,min_samples_split=5,n_estimators=50)
Finalmod.fit(X_train,Y_train)
pred=Finalmod.predict(X_test)
acc=accuracy_score(Y_test,pred)

cvs=cross_val_score(Finalmod,X,Y,cv=5)
Y_pred_prob=Finalmod.predict_proba(X_test)[:,1]
fpr,tpr,thresholds=roc_curve(Y_test,Y_pred_prob)
auc_score=roc_auc_score(Y_test,Finalmod.predict(X_test))

print('RFC Performance after HyperTuning')
print('-----------------------------------------------')
print('Accuracy Score',acc*100)
print('Cross Validation Score',cvs.mean()*100)
print('AUC ROC Score',auc_score*100)
print('\n')
print('AUC ROC Curve with Final Mod')
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label=RandomForestClassifier)
plt.xlabel('False Positive rate')
plt.ylabel('True Positive rate')
plt.title(Finalmod)
plt.show()
# Out:
# RFC Performance after HyperTuning
# -----------------------------------------------
# Accuracy Score 85.09516837481699
# Cross Validation Score 83.91130630914606
# AUC ROC Score 85.09048418764895
#
#
# AUC ROC Curve with Final Mod

# %% [markdown]
# # Saving the model:

# %%
import joblib
joblib.dump(rfc,"final_Customer_Churn_Analysis.pkl")
# Out:
# ['final_Customer_Churn_Analysis.pkl']
